# %% [markdown]
# # Challenge 1: Get weather description and amount of precipitation for each city

# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random lat and lng combos
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats,lngs)

# %%
# Add lats and lngs to a list
coordinates = list(lat_lngs)

# %%
# Create new list to hold cities
cities = []

# Identify nearest city for each lat and lng combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If city is unique then add it to the city list
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 622

# %%
# Import the request library
import requests

from datetime import datetime
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval")
print("-" * 25)


# Create counter
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
    # Creats endpoint URL with each city
    city_url = f'{url}&q={city.replace(" ", "+")}'
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_snow_inches = 0
            
        # Append city info into city data
        city_data.append(
        {
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Current Description": city_weather_description,
            "Rain (inches)": city_rain_inches,
            "Snow (inches)": city_snow_inches,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country
        })
    except:
        print("City Not Found. Skipping....")
        pass
# Indicated data load complete
print("-" * 25)
print("Data Retrieval Complete")
print("-" * 25)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | kirakira
# Processing Record 2 of Set 1 | flinders
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | fukue
# Processing Record 7 of Set 1 | stanari
# Processing Record 8 of Set 1 | amalapuram
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | cananeia
# Processing Record 13 of Set 1 | chuy
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | atar
# Processing Record 16 of Set 1 | den helder
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | labutta
# City Not Found. Skipping....
# Processing Record 19 of Set 1 | vao
# Processing Record 20 of Set 1 | hervey bay
# Processing Record 21 of Set 1 | sao jose da coroa grande
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | yeppoon
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | kyra
# Processing Record 27 of Set 1 | salinas
# Processing Record 28 of Set 1 | laguna
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | mayumba
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | colares
# Processing Record 33 of Set 1 | beira
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | cumberland
# Processing Record 40 of Set 1 | hualmay
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | cherskiy
# Processing Record 43 of Set 1 | namatanai
# Processing Record 44 of Set 1 | novorudnyy
# Processing Record 45 of Set 1 | taoudenni
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | faanui
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | olga
# Processing Record 50 of Set 1 | taolanaro
# City Not Found. Skipping....
# Processing Record 1 of Set 2 | bengkulu
# Processing Record 2 of Set 2 | dingle
# Processing Record 3 of Set 2 | talara
# Processing Record 4 of Set 2 | husavik
# Processing Record 5 of Set 2 | umzimvubu
# City Not Found. Skipping....
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | mutoko
# Processing Record 8 of Set 2 | luau
# Processing Record 9 of Set 2 | asau
# Processing Record 10 of Set 2 | sawakin
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | goroka
# Processing Record 13 of Set 2 | westport
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | tsumeb
# Processing Record 16 of Set 2 | barentsburg
# City Not Found. Skipping....
# Processing Record 17 of Set 2 | pemangkat
# Processing Record 18 of Set 2 | taitung
# Processing Record 19 of Set 2 | leningradskiy
# Processing Record 20 of Set 2 | carnarvon
# Processing Record 21 of Set 2 | san quintin
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | nieuw amsterdam
# Processing Record 26 of Set 2 | whyalla
# Processing Record 27 of Set 2 | moerai
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | yaan
# Processing Record 30 of Set 2 | torbay
# Processing Record 31 of Set 2 | los llanos de aridane
# Processing Record 32 of Set 2 | beruwala
# Processing Record 33 of Set 2 | rongcheng
# Processing Record 34 of Set 2 | cockburn town
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | beloha
# Processing Record 37 of Set 2 | keetmanshoop
# Processing Record 38 of Set 2 | lichinga
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | gat
# Processing Record 41 of Set 2 | hamilton
# Processing Record 42 of Set 2 | new norfolk
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | northam
# Processing Record 46 of Set 2 | kapustin yar
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 | te anau
# Processing Record 49 of Set 2 | shimoda
# Processing Record 50 of Set 2 | itabira
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | illoqqortoormiut
# City Not Found. Skipping....
# Processing Record 3 of Set 3 | omsukchan
# Processing Record 4 of Set 3 | nizwa
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | lavrentiya
# Processing Record 7 of Set 3 | luderitz
# Processing Record 8 of Set 3 | upington
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | pevek
# Processing Record 11 of Set 3 | bathsheba
# Processing Record 12 of Set 3 | naco
# Processing Record 13 of Set 3 | puerto ayora
# Processing Record 14 of Set 3 | longlac
# City Not Found. Skipping....
# Processing Record 15 of Set 3 | hofn
# Processing Record 16 of Set 3 | aranos
# Processing Record 17 of Set 3 | terme
# Processing Record 18 of Set 3 | mayo
# Processing Record 19 of Set 3 | solnechnyy
# Processing Record 20 of Set 3 | alotau
# City Not Found. Skipping....
# Processing Record 21 of Set 3 | sfantu gheorghe
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | halifax
# Processing Record 24 of Set 3 | aksu
# Processing Record 25 of Set 3 | hobart
# Processing Record 26 of Set 3 | shingu
# Processing Record 27 of Set 3 | khatanga
# Processing Record 28 of Set 3 | east london
# Processing Record 29 of Set 3 | brusturoasa
# Processing Record 30 of Set 3 | port alfred
# Processing Record 31 of Set 3 | doctor pedro p. pena
# City Not Found. Skipping....
# Processing Record 32 of Set 3 | anadyr
# Processing Record 33 of Set 3 | kopavogur
# Processing Record 34 of Set 3 | rocha
# Processing Record 35 of Set 3 | sain alto
# Processing Record 36 of Set 3 | baherden
# Processing Record 37 of Set 3 | broome
# Processing Record 38 of Set 3 | fergus falls
# Processing Record 39 of Set 3 | vaini
# Processing Record 40 of Set 3 | katsuura
# Processing Record 41 of Set 3 | ryotsu
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | rawson
# Processing Record 45 of Set 3 | novosergiyevka
# Processing Record 46 of Set 3 | banjar
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | shelburne
# Processing Record 49 of Set 3 | avarua
# Processing Record 50 of Set 3 | abu samrah
# Processing Record 1 of Set 4 | shenzhen
# Processing Record 2 of Set 4 | provideniya
# Processing Record 3 of Set 4 | kamenskoye
# City Not Found. Skipping....
# Processing Record 4 of Set 4 | portland
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | ambilobe
# Processing Record 7 of Set 4 | aksarayskiy
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | great falls
# Processing Record 10 of Set 4 | galiwinku
# City Not Found. Skipping....
# Processing Record 11 of Set 4 | saleaula
# City Not Found. Skipping....
# Processing Record 12 of Set 4 | amethi
# Processing Record 13 of Set 4 | yulara
# Processing Record 14 of Set 4 | san patricio
# Processing Record 15 of Set 4 | nybro
# Processing Record 16 of Set 4 | port lincoln
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | semporna
# Processing Record 19 of Set 4 | belushya guba
# City Not Found. Skipping....
# Processing Record 20 of Set 4 | stephenville
# Processing Record 21 of Set 4 | souillac
# Processing Record 22 of Set 4 | elko
# Processing Record 23 of Set 4 | roald
# Processing Record 24 of Set 4 | malko tarnovo
# Processing Record 25 of Set 4 | necochea
# Processing Record 26 of Set 4 | tanete
# Processing Record 27 of Set 4 | sulphur
# Processing Record 28 of Set 4 | port blair
# Processing Record 29 of Set 4 | dharchula
# Processing Record 30 of Set 4 | bilma
# Processing Record 31 of Set 4 | manggar
# Processing Record 32 of Set 4 | vila franca do campo
# Processing Record 33 of Set 4 | castro daire
# Processing Record 34 of Set 4 | vinh
# Processing Record 35 of Set 4 | iqaluit
# Processing Record 36 of Set 4 | kaitangata
# Processing Record 37 of Set 4 | yukamenskoye
# Processing Record 38 of Set 4 | jaciara
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | mabai
# Processing Record 41 of Set 4 | banda aceh
# Processing Record 42 of Set 4 | umm kaddadah
# Processing Record 43 of Set 4 | arraial do cabo
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | namibe
# Processing Record 46 of Set 4 | guerrero negro
# Processing Record 47 of Set 4 | cidreira
# Processing Record 48 of Set 4 | fort saint john
# City Not Found. Skipping....
# Processing Record 49 of Set 4 | saint george
# Processing Record 50 of Set 4 | sao filipe
# Processing Record 1 of Set 5 | atkarsk
# Processing Record 2 of Set 5 | talnakh
# Processing Record 3 of Set 5 | manta
# Processing Record 4 of Set 5 | grand river south east
# City Not Found. Skipping....
# Processing Record 5 of Set 5 | zhuhai
# Processing Record 6 of Set 5 | labuhan
# Processing Record 7 of Set 5 | mogadishu
# Processing Record 8 of Set 5 | amderma
# City Not Found. Skipping....
# Processing Record 9 of Set 5 | byron bay
# Processing Record 10 of Set 5 | calahorra
# Processing Record 11 of Set 5 | fort nelson
# Processing Record 12 of Set 5 | linjiang
# Processing Record 13 of Set 5 | jinxiang
# Processing Record 14 of Set 5 | port macquarie
# Processing Record 15 of Set 5 | logansport
# Processing Record 16 of Set 5 | pisco
# Processing Record 17 of Set 5 | norman wells
# Processing Record 18 of Set 5 | beyneu
# Processing Record 19 of Set 5 | tarata
# Processing Record 20 of Set 5 | bogorodskoye
# Processing Record 21 of Set 5 | majadahonda
# Processing Record 22 of Set 5 | riyadh
# Processing Record 23 of Set 5 | ust-maya
# Processing Record 24 of Set 5 | eirunepe
# Processing Record 25 of Set 5 | ancud
# Processing Record 26 of Set 5 | lagoa
# Processing Record 27 of Set 5 | leshukonskoye
# Processing Record 28 of Set 5 | otradnoye
# Processing Record 29 of Set 5 | genc
# Processing Record 30 of Set 5 | poum
# Processing Record 31 of Set 5 | najran
# Processing Record 32 of Set 5 | san cristobal
# Processing Record 33 of Set 5 | urumqi
# Processing Record 34 of Set 5 | sur
# Processing Record 35 of Set 5 | bambous virieux
# Processing Record 36 of Set 5 | sentyabrskiy
# City Not Found. Skipping....
# Processing Record 37 of Set 5 | kahului
# Processing Record 38 of Set 5 | pareora
# Processing Record 39 of Set 5 | valdepenas
# Processing Record 40 of Set 5 | musoma
# Processing Record 41 of Set 5 | jieshi
# Processing Record 42 of Set 5 | tasiilaq
# Processing Record 43 of Set 5 | saint-philippe
# Processing Record 44 of Set 5 | coahuayana
# Processing Record 45 of Set 5 | donegal
# Processing Record 46 of Set 5 | thohoyandou
# Processing Record 47 of Set 5 | penzance
# Processing Record 48 of Set 5 | severomuysk
# Processing Record 49 of Set 5 | warrington
# Processing Record 50 of Set 5 | ergani
# Processing Record 1 of Set 6 | alyangula
# Processing Record 2 of Set 6 | saint-georges
# Processing Record 3 of Set 6 | zhezkazgan
# Processing Record 4 of Set 6 | buchanan
# Processing Record 5 of Set 6 | high level
# Processing Record 6 of Set 6 | orillia
# Processing Record 7 of Set 6 | kembe
# Processing Record 8 of Set 6 | artyk
# City Not Found. Skipping....
# Processing Record 9 of Set 6 | biak
# Processing Record 10 of Set 6 | krasnyy chikoy
# Processing Record 11 of Set 6 | hokitika
# Processing Record 12 of Set 6 | nome
# Processing Record 13 of Set 6 | rio gallegos
# Processing Record 14 of Set 6 | kenora
# Processing Record 15 of Set 6 | nizhneyansk
# City Not Found. Skipping....
# Processing Record 16 of Set 6 | tiksi
# Processing Record 17 of Set 6 | ostrovnoy
# Processing Record 18 of Set 6 | vredendal
# Processing Record 19 of Set 6 | burica
# City Not Found. Skipping....
# Processing Record 20 of Set 6 | muroto
# Processing Record 21 of Set 6 | tazovskiy
# Processing Record 22 of Set 6 | geraldton
# Processing Record 23 of Set 6 | tambacounda
# Processing Record 24 of Set 6 | mao
# Processing Record 25 of Set 6 | piopio
# Processing Record 26 of Set 6 | dien bien
# City Not Found. Skipping....
# Processing Record 27 of Set 6 | nara
# Processing Record 28 of Set 6 | salekhard
# Processing Record 29 of Set 6 | haibowan
# City Not Found. Skipping....
# Processing Record 30 of Set 6 | mogzon
# Processing Record 31 of Set 6 | cabo san lucas
# Processing Record 32 of Set 6 | archidona
# Processing Record 33 of Set 6 | sibu
# Processing Record 34 of Set 6 | yarada
# Processing Record 35 of Set 6 | veraval
# Processing Record 36 of Set 6 | malibu
# Processing Record 37 of Set 6 | sidney
# Processing Record 38 of Set 6 | umarkot
# Processing Record 39 of Set 6 | at-bashi
# Processing Record 40 of Set 6 | mitu
# Processing Record 41 of Set 6 | bela
# Processing Record 42 of Set 6 | bowen
# Processing Record 43 of Set 6 | gunnedah
# Processing Record 44 of Set 6 | thinadhoo
# Processing Record 45 of Set 6 | baruun-urt
# Processing Record 46 of Set 6 | lakes entrance
# Processing Record 47 of Set 6 | srednekolymsk
# Processing Record 48 of Set 6 | lorengau
# Processing Record 49 of Set 6 | clyde river
# Processing Record 50 of Set 6 | havre-saint-pierre
# Processing Record 1 of Set 7 | udachnyy
# Processing Record 2 of Set 7 | praia da vitoria
# Processing Record 3 of Set 7 | axim
# Processing Record 4 of Set 7 | umea
# Processing Record 5 of Set 7 | richards bay
# Processing Record 6 of Set 7 | kaka
# Processing Record 7 of Set 7 | kudahuvadhoo
# Processing Record 8 of Set 7 | mabaruma
# Processing Record 9 of Set 7 | daru
# Processing Record 10 of Set 7 | henties bay
# Processing Record 11 of Set 7 | morondava
# Processing Record 12 of Set 7 | ilebo
# Processing Record 13 of Set 7 | guarda
# Processing Record 14 of Set 7 | chernyshevskiy
# Processing Record 15 of Set 7 | hongjiang
# Processing Record 16 of Set 7 | victoria
# Processing Record 17 of Set 7 | mayor pablo lagerenza
# Processing Record 18 of Set 7 | kampene
# Processing Record 19 of Set 7 | mys shmidta
# City Not Found. Skipping....
# Processing Record 20 of Set 7 | sao joao da barra
# Processing Record 21 of Set 7 | bhawanipatna
# Processing Record 22 of Set 7 | sabha
# Processing Record 23 of Set 7 | merauke
# Processing Record 24 of Set 7 | rincon
# Processing Record 25 of Set 7 | chikoy
# City Not Found. Skipping....
# Processing Record 26 of Set 7 | farah
# Processing Record 27 of Set 7 | tuyen quang
# Processing Record 28 of Set 7 | aripuana
# Processing Record 29 of Set 7 | dakar
# Processing Record 30 of Set 7 | kirs
# Processing Record 31 of Set 7 | kushima
# Processing Record 32 of Set 7 | halden
# Processing Record 33 of Set 7 | touros
# Processing Record 34 of Set 7 | markova
# Processing Record 35 of Set 7 | kieta
# Processing Record 36 of Set 7 | mosetse
# Processing Record 37 of Set 7 | kruisfontein
# Processing Record 38 of Set 7 | virginia beach
# Processing Record 39 of Set 7 | karsun
# Processing Record 40 of Set 7 | vanavara
# Processing Record 41 of Set 7 | isangel
# Processing Record 42 of Set 7 | esperance
# Processing Record 43 of Set 7 | almeria
# Processing Record 44 of Set 7 | hami
# Processing Record 45 of Set 7 | tabou
# Processing Record 46 of Set 7 | abu kamal
# Processing Record 47 of Set 7 | alcudia
# Processing Record 48 of Set 7 | barkhan
# Processing Record 49 of Set 7 | itarema
# Processing Record 50 of Set 7 | coralville
# Processing Record 1 of Set 8 | verkhnevilyuysk
# Processing Record 2 of Set 8 | port hardy
# Processing Record 3 of Set 8 | lasa
# Processing Record 4 of Set 8 | upata
# Processing Record 5 of Set 8 | linfen
# Processing Record 6 of Set 8 | kupang
# Processing Record 7 of Set 8 | gorontalo
# Processing Record 8 of Set 8 | dauriya
# Processing Record 9 of Set 8 | porto walter
# Processing Record 10 of Set 8 | ankang
# Processing Record 11 of Set 8 | orange cove
# Processing Record 12 of Set 8 | barcelos
# Processing Record 13 of Set 8 | ust-kuyga
# Processing Record 14 of Set 8 | gereykhanovskoye
# Processing Record 15 of Set 8 | santa isabel do rio negro
# Processing Record 16 of Set 8 | coquimbo
# Processing Record 17 of Set 8 | inderborskiy
# City Not Found. Skipping....
# Processing Record 18 of Set 8 | aykhal
# Processing Record 19 of Set 8 | charters towers
# Processing Record 20 of Set 8 | vardo
# Processing Record 21 of Set 8 | takoradi
# Processing Record 22 of Set 8 | buala
# Processing Record 23 of Set 8 | antofagasta
# Processing Record 24 of Set 8 | vestmannaeyjar
# Processing Record 25 of Set 8 | tsihombe
# City Not Found. Skipping....
# Processing Record 26 of Set 8 | nelson bay
# Processing Record 27 of Set 8 | shiraz
# Processing Record 28 of Set 8 | narowal
# Processing Record 29 of Set 8 | mehamn
# Processing Record 30 of Set 8 | ahipara
# Processing Record 31 of Set 8 | diffa
# Processing Record 32 of Set 8 | ozgon
# City Not Found. Skipping....
# Processing Record 33 of Set 8 | diamantino
# Processing Record 34 of Set 8 | aklavik
# Processing Record 35 of Set 8 | vaitupu
# City Not Found. Skipping....
# Processing Record 36 of Set 8 | yanam
# Processing Record 37 of Set 8 | sept-iles
# Processing Record 38 of Set 8 | chapais
# Processing Record 39 of Set 8 | vilyuysk
# Processing Record 40 of Set 8 | alofi
# Processing Record 41 of Set 8 | ayios kirikos
# City Not Found. Skipping....
# Processing Record 42 of Set 8 | singapore
# Processing Record 43 of Set 8 | ngama
# Processing Record 44 of Set 8 | teahupoo
# Processing Record 45 of Set 8 | tashtyp
# Processing Record 46 of Set 8 | grand gaube
# Processing Record 47 of Set 8 | salta
# Processing Record 48 of Set 8 | laives
# Processing Record 49 of Set 8 | oranjestad
# Processing Record 50 of Set 8 | samtredia
# Processing Record 1 of Set 9 | mandalgovi
# Processing Record 2 of Set 9 | avera
# Processing Record 3 of Set 9 | dolores
# Processing Record 4 of Set 9 | bida
# Processing Record 5 of Set 9 | usinsk
# Processing Record 6 of Set 9 | saint-pierre
# Processing Record 7 of Set 9 | pitimbu
# Processing Record 8 of Set 9 | casablanca
# Processing Record 9 of Set 9 | la ronge
# Processing Record 10 of Set 9 | wad madani
# Processing Record 11 of Set 9 | ketchikan
# Processing Record 12 of Set 9 | buta
# Processing Record 13 of Set 9 | terra boa
# Processing Record 14 of Set 9 | pombas
# Processing Record 15 of Set 9 | hihifo
# City Not Found. Skipping....
# Processing Record 16 of Set 9 | abha
# Processing Record 17 of Set 9 | prince rupert
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | baiyin
# Processing Record 20 of Set 9 | palabuhanratu
# City Not Found. Skipping....
# Processing Record 21 of Set 9 | xinzhi
# Processing Record 22 of Set 9 | bintulu
# Processing Record 23 of Set 9 | maniitsoq
# Processing Record 24 of Set 9 | dunedin
# Processing Record 25 of Set 9 | kailua
# Processing Record 26 of Set 9 | maryborough
# Processing Record 27 of Set 9 | sisophon
# Processing Record 28 of Set 9 | mumford
# Processing Record 29 of Set 9 | poronaysk
# Processing Record 30 of Set 9 | samusu
# City Not Found. Skipping....
# Processing Record 31 of Set 9 | karamea
# City Not Found. Skipping....
# Processing Record 32 of Set 9 | olinda
# Processing Record 33 of Set 9 | luangwa
# Processing Record 34 of Set 9 | tarakan
# Processing Record 35 of Set 9 | yining
# Processing Record 36 of Set 9 | jurbarkas
# Processing Record 37 of Set 9 | obo
# Processing Record 38 of Set 9 | bara
# Processing Record 39 of Set 9 | shemursha
# Processing Record 40 of Set 9 | bentiu
# Processing Record 41 of Set 9 | tuatapere
# Processing Record 42 of Set 9 | matara
# Processing Record 43 of Set 9 | coihaique
# Processing Record 44 of Set 9 | acarau
# Processing Record 45 of Set 9 | ilulissat
# Processing Record 46 of Set 9 | chadiza
# Processing Record 47 of Set 9 | miracema do tocantins
# Processing Record 48 of Set 9 | gorkovskoye
# City Not Found. Skipping....
# Processing Record 49 of Set 9 | fethiye
# Processing Record 50 of Set 9 | panguna
# Processing Record 1 of Set 10 | vestmanna
# Processing Record 2 of Set 10 | calama
# Processing Record 3 of Set 10 | sangin
# Processing Record 4 of Set 10 | pacasmayo
# Processing Record 5 of Set 10 | dongsheng
# Processing Record 6 of Set 10 | rio grande
# Processing Record 7 of Set 10 | qingdao
# Processing Record 8 of Set 10 | meridian
# Processing Record 9 of Set 10 | kheda
# Processing Record 10 of Set 10 | bindura
# Processing Record 11 of Set 10 | porto belo
# Processing Record 12 of Set 10 | catuday
# Processing Record 13 of Set 10 | mullaitivu
# City Not Found. Skipping....
# Processing Record 14 of Set 10 | meulaboh
# Processing Record 15 of Set 10 | verkhnyaya khava
# Processing Record 16 of Set 10 | fiumicino
# Processing Record 17 of Set 10 | kalemie
# Processing Record 18 of Set 10 | grindavik
# Processing Record 19 of Set 10 | along
# Processing Record 20 of Set 10 | atchison
# Processing Record 21 of Set 10 | redmond
# Processing Record 22 of Set 10 | abu dhabi
# Processing Record 23 of Set 10 | estevan
# Processing Record 24 of Set 10 | akureyri
# Processing Record 25 of Set 10 | nokaneng
# Processing Record 26 of Set 10 | turukhansk
# Processing Record 27 of Set 10 | chunoyar
# Processing Record 28 of Set 10 | attawapiskat
# City Not Found. Skipping....
# Processing Record 29 of Set 10 | zlatoustovsk
# City Not Found. Skipping....
# Processing Record 30 of Set 10 | ambulu
# Processing Record 31 of Set 10 | stepnyak
# Processing Record 32 of Set 10 | lengshuitan
# Processing Record 33 of Set 10 | champerico
# Processing Record 34 of Set 10 | qui nhon
# Processing Record 35 of Set 10 | jijiga
# Processing Record 36 of Set 10 | goderich
# Processing Record 37 of Set 10 | rundu
# Processing Record 38 of Set 10 | igarka
# Processing Record 39 of Set 10 | quatre cocos
# Processing Record 40 of Set 10 | puerto escondido
# Processing Record 41 of Set 10 | krasnoselkup
# Processing Record 42 of Set 10 | iwaki
# Processing Record 43 of Set 10 | askarovo
# Processing Record 44 of Set 10 | weligama
# Processing Record 45 of Set 10 | mount gambier
# Processing Record 46 of Set 10 | southwick
# Processing Record 47 of Set 10 | goya
# Processing Record 48 of Set 10 | eureka
# Processing Record 49 of Set 10 | padang
# Processing Record 50 of Set 10 | inta
# Processing Record 1 of Set 11 | burnie
# Processing Record 2 of Set 11 | hede
# Processing Record 3 of Set 11 | suluq
# Processing Record 4 of Set 11 | kalaswala
# Processing Record 5 of Set 11 | lilongwe
# Processing Record 6 of Set 11 | beringovskiy
# Processing Record 7 of Set 11 | boulder city
# Processing Record 8 of Set 11 | crotone
# Processing Record 9 of Set 11 | bani walid
# Processing Record 10 of Set 11 | yar-sale
# Processing Record 11 of Set 11 | mount isa
# Processing Record 12 of Set 11 | nabire
# Processing Record 13 of Set 11 | rengo
# Processing Record 14 of Set 11 | hagenow
# Processing Record 15 of Set 11 | palmer
# Processing Record 16 of Set 11 | wilmington
# Processing Record 17 of Set 11 | saint-augustin
# Processing Record 18 of Set 11 | gornopravdinsk
# Processing Record 19 of Set 11 | pathein
# Processing Record 20 of Set 11 | burns lake
# Processing Record 21 of Set 11 | san francisco menendez
# Processing Record 22 of Set 11 | sistranda
# Processing Record 23 of Set 11 | vanimo
# Processing Record 24 of Set 11 | ulaangom
# Processing Record 25 of Set 11 | sedelnikovo
# City Not Found. Skipping....
# Processing Record 26 of Set 11 | vostok
# Processing Record 27 of Set 11 | oranjemund
# Processing Record 28 of Set 11 | morristown
# Processing Record 29 of Set 11 | rutland
# Processing Record 30 of Set 11 | abnub
# Processing Record 31 of Set 11 | pietrasanta
# Processing Record 32 of Set 11 | port-cartier
# Processing Record 33 of Set 11 | aloja
# Processing Record 34 of Set 11 | marcona
# City Not Found. Skipping....
# Processing Record 35 of Set 11 | ubinskoye
# Processing Record 36 of Set 11 | caravelas
# Processing Record 37 of Set 11 | dudinka
# Processing Record 38 of Set 11 | sadri
# Processing Record 39 of Set 11 | lazaro cardenas
# Processing Record 40 of Set 11 | kishapu
# Processing Record 41 of Set 11 | inhambane
# Processing Record 42 of Set 11 | russell
# Processing Record 43 of Set 11 | lumberton
# Processing Record 44 of Set 11 | mastung
# Processing Record 45 of Set 11 | haines junction
# Processing Record 46 of Set 11 | dzhebariki-khaya
# Processing Record 47 of Set 11 | grevesmuhlen
# Processing Record 48 of Set 11 | faya
# Processing Record 49 of Set 11 | atambua
# Processing Record 50 of Set 11 | dalby
# Processing Record 1 of Set 12 | mlimba
# Processing Record 2 of Set 12 | tilichiki
# Processing Record 3 of Set 12 | lata
# Processing Record 4 of Set 12 | slave lake
# Processing Record 5 of Set 12 | chkalovskoye
# Processing Record 6 of Set 12 | phan rang
# City Not Found. Skipping....
# Processing Record 7 of Set 12 | palaiomanina
# City Not Found. Skipping....
# Processing Record 8 of Set 12 | camacha
# Processing Record 9 of Set 12 | ginda
# Processing Record 10 of Set 12 | ozernovskiy
# Processing Record 11 of Set 12 | mackenzie
# Processing Record 12 of Set 12 | omboue
# Processing Record 13 of Set 12 | ugoofaaru
# Processing Record 14 of Set 12 | garden city
# Processing Record 15 of Set 12 | nehe
# Processing Record 16 of Set 12 | dwarka
# Processing Record 17 of Set 12 | brownsville
# Processing Record 18 of Set 12 | berlevag
# Processing Record 19 of Set 12 | katesh
# Processing Record 20 of Set 12 | ambodifototra
# City Not Found. Skipping....
# Processing Record 21 of Set 12 | tshikapa
# Processing Record 22 of Set 12 | palembang
# Processing Record 23 of Set 12 | balkhash
# Processing Record 24 of Set 12 | benjamin hill
# Processing Record 25 of Set 12 | cayenne
# Processing Record 26 of Set 12 | hopkinsville
# Processing Record 27 of Set 12 | polunochnoye
# Processing Record 28 of Set 12 | fevralsk
# City Not Found. Skipping....
# Processing Record 29 of Set 12 | rameswaram
# Processing Record 30 of Set 12 | hushitai
# Processing Record 31 of Set 12 | kneza
# City Not Found. Skipping....
# Processing Record 32 of Set 12 | khovu-aksy
# Processing Record 33 of Set 12 | timra
# Processing Record 34 of Set 12 | namtsy
# Processing Record 35 of Set 12 | samarai
# Processing Record 36 of Set 12 | tome
# Processing Record 37 of Set 12 | baghdad
# Processing Record 38 of Set 12 | babushkin
# Processing Record 39 of Set 12 | kaniv
# Processing Record 40 of Set 12 | roma
# Processing Record 41 of Set 12 | saint-francois
# Processing Record 42 of Set 12 | reading
# Processing Record 43 of Set 12 | sabaudia
# Processing Record 44 of Set 12 | sokolka
# Processing Record 45 of Set 12 | nathdwara
# Processing Record 46 of Set 12 | port hedland
# Processing Record 47 of Set 12 | utiroa
# City Not Found. Skipping....
# Processing Record 48 of Set 12 | mitsamiouli
# Processing Record 49 of Set 12 | araouane
# Processing Record 50 of Set 12 | olafsvik
# Processing Record 1 of Set 13 | kashmor
# Processing Record 2 of Set 13 | chagda
# City Not Found. Skipping....
# Processing Record 3 of Set 13 | tabiauea
# City Not Found. Skipping....
# Processing Record 4 of Set 13 | villazon
# Processing Record 5 of Set 13 | vila
# Processing Record 6 of Set 13 | nushki
# Processing Record 7 of Set 13 | korla
# Processing Record 8 of Set 13 | salalah
# Processing Record 9 of Set 13 | huarmey
# Processing Record 10 of Set 13 | wewak
# Processing Record 11 of Set 13 | florida
# Processing Record 12 of Set 13 | senador pompeu
# Processing Record 13 of Set 13 | winnemucca
# Processing Record 14 of Set 13 | malakal
# Processing Record 15 of Set 13 | bud
# Processing Record 16 of Set 13 | kununurra
# Processing Record 17 of Set 13 | christchurch
# Processing Record 18 of Set 13 | ayorou
# Processing Record 19 of Set 13 | bereda
# Processing Record 20 of Set 13 | boyabat
# Processing Record 21 of Set 13 | tres arroyos
# Processing Record 22 of Set 13 | ranong
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
len(city_data)
# Out:
# 576

# %%
# Convert array of dicts to dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp Current Description  Rain (inches)  \
# 0      kirakira -10.45  161.92     83.23          light rain           0.21
# 1      flinders -34.58  150.86     64.00          light rain           0.23
# 2       mataura -46.19  168.86     46.13       broken clouds           0.00
# 3  punta arenas -53.15  -70.92     33.80          few clouds           0.00
# 4         kapaa  22.08 -159.32     80.60           clear sky           0.00
# 5         fukue  32.69  128.84     80.60       broken clouds           0.00
# 6       stanari  44.75   17.83     57.20          few clouds           0.00
# 7    amalapuram  16.58   82.02     89.60    scattered clouds           0.00
# 8        kodiak  57.79 -152.41     51.80     overcast clouds           0.00
# 9     busselton -33.65  115.33     62.01     overcast clouds           0.00
#
#    Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.21        71         100        2.42      SB
# 1           0.23        65          51       13.00      AU
# 2           0.00        92          83        3.04      NZ
# 3           0.00        69          18        6.93      CL
# 4           0.00        69           1       12.75      US
# 5           0.00        78          75       17.22      JP
# 6           0.00        82          11        6.93      BA
# 7           0.00        62          40        6.93      IN
# 8           0.00        81          90       10.29      US
# 9           0.00        59          99        1.99      AU

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description',
#        'Rain (inches)', 'Snow (inches)', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country'],
#       dtype='object')

# %%
new_column_order = sorted(city_data_df.columns.tolist())
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City  Cloudiness Country Current Description  Humidity    Lat  \
# 0        kirakira         100      SB          light rain        71 -10.45
# 1        flinders          51      AU          light rain        65 -34.58
# 2         mataura          83      NZ       broken clouds        92 -46.19
# 3    punta arenas          18      CL          few clouds        69 -53.15
# 4           kapaa           1      US           clear sky        69  22.08
# ..            ...         ...     ...                 ...       ...    ...
# 571        ayorou          11      NE          few clouds        46  14.73
# 572        bereda           5      ES           clear sky       100  43.27
# 573       boyabat          40      TR    scattered clouds        88  41.47
# 574  tres arroyos         100      AR     overcast clouds        60 -38.37
# 575        ranong          40      TH    scattered clouds        66   9.97
#
#         Lng  Max Temp  Rain (inches)  Snow (inches)  Wind Speed
# 0    161.92     83.23           0.21           0.21        2.42
# 1    150.86     64.00           0.23           0.23       13.00
# 2    168.86     46.13           0.00           0.00        3.04
# 3    -70.92     33.80           0.00           0.00        6.93
# 4   -159.32     80.60           0.00           0.00       12.75
# ..      ...       ...            ...            ...         ...
# 571    0.92     87.71           0.00           0.00       11.79
# 572   -7.54     62.01           0.00           0.00        1.99
# 573   34.77     71.60           0.00           0.00       12.75
# 574  -60.28     44.42           0.00           0.00        1.21
# 575   98.63     89.60           0.00           0.00        4.70
#
# [576 rows x 11 columns]

# %%
city_data_df.dtypes
# Out:
# City                    object
# Cloudiness               int64
# Country                 object
# Current Description     object
# Humidity                 int64
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Rain (inches)          float64
# Snow (inches)          float64
# Wind Speed             float64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head()
# Out:
#                         City  Cloudiness Country Current Description  \
# 0                   kirakira         100      SB          light rain
# 1                   flinders          51      AU          light rain
# 12                      chuy         100      UY          light rain
# 19  sao jose da coroa grande           6      BR          light rain
# 20                    albany          82      US          light rain
#
#     Humidity    Lat     Lng  Max Temp  Rain (inches)  Snow (inches)  \
# 0         71 -10.45  161.92     83.23           0.21           0.21
# 1         65 -34.58  150.86     64.00           0.23           0.23
# 12        94 -33.70  -53.46     64.18           0.16           0.16
# 19        85  -8.90  -35.15     74.71           0.26           0.26
# 20        74  42.60  -73.97     78.01           0.19           0.19
#
#     Wind Speed
# 0         2.42
# 1        13.00
# 12        0.72
# 19        7.92
# 20        1.01

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head()
# Out:
#                         City  Cloudiness Country Current Description  \
# 0                   kirakira         100      SB          light rain
# 1                   flinders          51      AU          light rain
# 12                      chuy         100      UY          light rain
# 19  sao jose da coroa grande           6      BR          light rain
# 20                    albany          82      US          light rain
#
#     Humidity    Lat     Lng  Max Temp  Rain (inches)  Snow (inches)  \
# 0         71 -10.45  161.92     83.23           0.21           0.21
# 1         65 -34.58  150.86     64.00           0.23           0.23
# 12        94 -33.70  -53.46     64.18           0.16           0.16
# 19        85  -8.90  -35.15     74.71           0.26           0.26
# 20        74  42.60  -73.97     78.01           0.19           0.19
#
#     Wind Speed
# 0         2.42
# 1        13.00
# 12        0.72
# 19        7.92
# 20        1.01

# %%
# create csv output file
output_data_file = "data/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
